# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### Graph 1

# %% [markdown]
# Evolucion ICP en España (https://www.msn.com/es-es/entretenimiento/tv/gr%C3%A1ficas-manipuladas-vs-la-realidad-indignaci%C3%B3n-por-otro-error-en-el-programa-de-ana-rosa-ahora-con-el-ipc/ar-AA13yXIW)
#
# ![alt text](ipc.jpg)

# %%
# Datos
x = ["ENE","FEB","MAR","ABR","MAY","JUN","JUL","AGO","SEPT","OCT"]
y = [6.1,7.6,9.8,8.3,8.7,10.2,10.8,10.5,8.9,7.3]

# Crear la gráfica
fig, ax = plt.subplots(figsize=(10, 6))
bars = ax.bar(x, y, color='#2D87BB', width=0.5)

# Agregar etiquetas de valor encima de las barras
for i, bar in enumerate(bars):
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2., height+0.2, '%.1f' % height,
            ha='center', va='bottom', color='black', fontsize=12, fontweight='bold')

# Remover la escala en el eje y
ax.set_yticks([])

# Cambiar los colores de fondo y de los ejes
fig.set_facecolor('#E5E5E5')
ax.set_facecolor('#E5E5E5')
ax.spines['bottom'].set_color('gray')
ax.spines['top'].set_color('gray')
ax.spines['right'].set_color('gray')
ax.spines['left'].set_color('gray')

# Añadir títulos y etiquetas de los ejes
plt.title("Evolución del ICP", fontsize=20, fontweight='bold', color='#333333')
plt.xlabel("Meses", fontsize=14, fontweight='bold', color='#333333')

# Cambiar el tamaño de la fuente de los ticks del eje x
plt.xticks(fontsize=12)
plt.ylim(0,12)
# Mostrar la gráfica
plt.show()

# %% [markdown]
# #### Graph 2

# %% [markdown]
# Madrid españa:  número de muertos por coronavirus en Madrid (https://www.elconfidencial.com/television/programas-tv/2020-10-29/telemadrid-juntos-grafico-manipulado-muertos-covid19-coronavirus_2811219/)
#
# ![alt text](fallecidos.jpg)

# %%
x=["27 Septiembre","27 Octubre"]
y=[1136,1056]

# Crear la gráfica
fig, ax = plt.subplots(figsize=(10, 6))
bars = ax.bar(x, y, color='red', width=0.3)

# Agregar etiquetas de valor encima de las barras

for i, bar in enumerate(bars):
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2., height+0.2, '%.1f' % height,
            ha='center', va='bottom', color='black', fontsize=12, fontweight='bold')


# Remover la escala en el eje y
ax.set_yticks([])

# Cambiar los colores de fondo y de los ejes
fig.set_facecolor('#E5E5E5')
ax.set_facecolor('#E5E5E5')
ax.spines['bottom'].set_color('gray')
ax.spines['top'].set_color('gray')
ax.spines['right'].set_color('gray')
ax.spines['left'].set_color('gray')

# Añadir títulos y etiquetas de los ejes
plt.title("Fallecidos", fontsize=20, fontweight='bold', color='#333333')
plt.xlabel("Mes", fontsize=14, fontweight='bold', color='#333333')

# Cambiar el tamaño de la fuente de los ticks del eje x
plt.xticks(fontsize=12)
# Mostrar la gráfica
plt.show()

# %% [markdown]
# #### Graph 3

# %% [markdown]
# Registro de desempleo español (https://cadenaser.com/ser/2016/02/01/television/1454322989_665803.html):
#
#
# ![alt text](registrodesempleo.jpg)

# %%
import matplotlib.pyplot as plt

# Datos
x = [2007, 2009, 2012, 2014]
y = [2129547, 4100073, 4848723, 4447711]

# Crear la gráfica
fig, ax = plt.subplots(figsize=(10, 6))
line = ax.plot(x, y, color='red')

# Agregar etiquetas de valor encima de la línea
for i, val in enumerate(y):
    numero=format(val, ',')
    ax.text(x[i], val+30000, numero,#'%d' % int(val),
            ha='center', va='bottom', color='black', fontsize=12, fontweight='bold')

# Remover la escala en el eje y
ax.set_yticks([])

# Cambiar los colores de fondo y de los ejes
fig.set_facecolor('#E5E5E5')
ax.set_facecolor('#E5E5E5')
ax.spines['bottom'].set_color('gray')
ax.spines['top'].set_color('gray')
ax.spines['right'].set_color('gray')
ax.spines['left'].set_color('gray')

# Añadir títulos y etiquetas de los ejes
plt.title("Registro de desempleo", fontsize=20, fontweight='bold', color='#333333')
plt.xlabel("Años", fontsize=14, fontweight='bold', color='#333333')

# Cambiar el tamaño de la fuente de los ticks del eje x
plt.xticks(fontsize=12)

# Mostrar la gráfica
plt.show()

# %% [markdown]
# ### Good graphs:

# %% [markdown]
# #### Graph1

# %% [markdown]
# The population of USA (https://homework.study.com/explanation/the-bar-graph-shows-the-population-of-the-united-states-in-millions-for-six-selected-years-here-are-two-functions-that-model-the-data-m-x-1-53x-plus-114-8-f-x-1-46x-plus-120-7-does-the-result-overestimate-or-underestimate-the-actual-difference-betw.html)
#
# ![alt text](populationUSA.jpg)

# %% [markdown]
# Global Economy to End Decade on a Low Note  (https://www.statista.com/chart/20078/estimated-worldwide-real-gdp-growth/)
#
# ![alt text](globaleconomy.jpeg)

# %% [markdown]
# How much watre do we use?  (https://www.statisticshowto.com/probability-and-statistics/descriptive-statistics/pie-chart/)
#
#
#
# ![alt text](water.png)
